# %%
s = 'String'

# %% [markdown]
# ![s](Img/String.png)

# %%
s = "Python Program"

# %%
s[0]
# Out:
# 'P'

# %%
s[-1]
# Out:
# 'm'

# %%
s[13]
# Out:
# 'm'

# %%
len(s)
# Out:
# 14

# %%
len(s) - 1
# Out:
# 13

# %%
s[len(s) - 1]
# Out:
# 'm'

# %%
s = "Python Program"

# %%
s[-14]
# Out:
# 'f'

# %%
s[len(s) - 1]
# Out:
# 'f'

# %%
-len(s)
# Out:
# -14

# %%
s[-len(s)]
# Out:
# 'P'

# %% [markdown]
# # Slicing

# %%
s = "Python Program"

# %% [markdown]
# # mystr[start_index:stop_idex]

# %%
city = "Hyderabad"

# %%
city[3:6]
# Out:
# 'era'

# %%
city[3:-3]
# Out:
# 'era'

# %%
city[-6:6]
# Out:
# 'era'

# %%
city[-6:-3]
# Out:
# 'era'

# %%
city[6:3]
# Out:
# ''

# %%
city[-3:-6]
# Out:
# ''

# %%
s = "Python Program"

# %%
s[7:11]
# Out:
# 'Prog'

# %%
s[-7:-3]
# Out:
# 'Prog'

# %%
s[0:6]
# Out:
# 'Python'

# %%
s[:6]
# Out:
# 'Python'

# %%
s[7:]
# Out:
# 'Program'

# %% [markdown]
# # mystr[start_index:stop_idex: step ]

# %%
s = "Python Program"

# %%
s[::2]
# Out:
# 'Pto rga'

# %%
s[2::2]
# Out:
# 'to rga'

# %%
s[2:7:2]
# Out:
# 'to '

# %%
import numpy as np

# %%
np.random.randint(2)
# Out:
# 0

# %%
s[np.random.randint(7):2]
# Out:
# ''

# %% [markdown]
# # Membership Operqtors

# %%
st = "Paris is capital of Fashion, Hyderabad is software hub"

# %%
# in , not in

# %%
'Paris' in st
# Out:
# True

# %%
'France' in st
# Out:
# False

# %%
'Hyderabad' not in st
# Out:
# False

# %%
'hyderabad' not in st
# Out:
# True

# %% [markdown]
# #### Try modifying

# %%
st = 'Pune'

# %%
st[1] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3592/47394548.py in <module>
# ----> 1 st[1] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # String Methods

# %% [markdown]
# - replace()
# - upper ()
# - lower ()
# - strip()
# - index()
# - count(substring, start,end)

# %%
# replace()

# %%
st = 'Pune'

# %%
st.replace('u','a')
# Out:
# 'Pane'

# %%
st
# Out:
# 'Pune'

# %%
st1 = st.replace('u','a')

# %%
st1
# Out:
# 'Pane'

# %%
st = 'hyderabad'

# %%
s = st.upper()

# %%
s
# Out:
# 'HYDERABAD'

# %%
st
# Out:
# 'hyderabad'

# %%
s.lower()
# Out:
# 'hyderabad'

# %%
# strip()

# %%
sent = " There is a space at the end  "

# %%
sent
# Out:
# ' There is a space at the end  '

# %%
print(sent.strip())
# Out:
# There is a space at the end

# %%
print(sent)

# %%
i = '%%%%%%4%4%%%%%'

# %%
i.strip('%')
# Out:
# '4%4'

# %%
st = '#######*44#*************'

# %%
st.strip('#*')
# Out:
# '44'

# %%
st.lstrip('#').rstrip('*')
# Out:
# '*44#'

# %%
string = '######*$$$$$$$----Mango#********??????'

# %%
string.strip('#*$-?')
# Out:
# 'Mango'

# %%
# Count

# %%
string = "Python is awesome, isn't it"

# %%
string.count('is')
# Out:
# 2

# %%
string.count('is',18)
# Out:
# 1

# %%
string.count('is',10,17)

# %%
# index()

# %%
string = "Python is awesome, isn't it"

# %%
string.index('a')
# Out:
# 10

# %%
string.index('k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3592/2690313244.py in <module>
# ----> 1 string.index('k')
#
# ValueError: substring not found

# %%
string.find('a')
# Out:
# 10

# %%
string.find('k')
# Out:
# -1

# %%
#email = 'hi@gmail.com'
# email = 'ram@rediffmail.com'
email = 'amazon123@yahoo.com'
# email = 'dfadgasdgsdfgsdfgdfg@amazon.com'

# %%
#email = 'hi@gmail.com'
# email = 'oh@yahoo.com'

# %%
email[3:]
# Out:
# 'yahoo.com'

# %%
email.index('@') + 1
# Out:
# 4

# %%
email[email.index('@') + 1 : ]
# Out:
# 'yahoo.com'
