# %% [markdown]
# - Stores the elements as key pair values
# - key is like an index , it is always unique
# - Values are objects that contain the information
# - Values are accessed using keys
# - Keys and values separated colons
# - key are immutable
# - values can be of mutable/immuatable , it can dulplicates
# - Each element is separated by comma

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d = {1:'Hi' , 2: 'Hello'}

# %%
type(d)
# Out:
# dict

# %%
len(d)
# Out:
# 2

# %%
d = {'Hi':1 , 'Hello': 2}

# %%
d = {"India":"INR", "USA":"USD", "France": "Euros"}

# %%
d1 = {[1,2,3]: 'Hi' , [4,5,6]: 'Hello'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11412/3651387048.py in <module>
# ----> 1 d1 = {[1,2,3]: 'Hi' , [4,5,6]: 'Hello'}
#
# TypeError: unhashable type: 'list'

# %%
d2 = {(1,2,3): 'Hi' , (4,5,6): 'Hello'}

# %%
# Create a dictionary

d = {"India":"INR", "USA":"USD", "France": "Euros"}

# %%
type(d)
# Out:
# dict

# %%
d['France']
# Out:
# 'Euros'

# %%
d["USA"] = "$"

# %%
d
# Out:
# {'India': 'INR', 'USA': '$', 'France': 'Euros'}

# %%
d2[(1,2,3)]
# Out:
# 'Hi'

# %%
d['Japan'] = "Yen"

# %%
d
# Out:
# {'India': 'INR', 'USA': '$', 'France': 'Euros', 'Japan': 'Yen'}

# %%
student_cour = {1234 : ['AI', 'Pyhton'] , 2345 : ['Java', 'AWS']}

# %%
student_cour[2345]
# Out:
# ['Java', 'AWS']

# %%
# items
d.items()
# Out:
# dict_items([('India', 'INR'), ('USA', '$'), ('France', 'Euros'), ('Japan', 'Yen')])

# %%
dnew = dict([('India', 'INR'), ('USA', '$'), ('France', 'Euros'), ('Japan', 'Yen')])

# %%
dnew
# Out:
# {'India': 'INR', 'USA': '$', 'France': 'Euros', 'Japan': 'Yen'}

# %%
dict([('India', 'INR'), ('USA', '$'), ('USA', ['USD', '$']), ('France', 'Euros'), ('Japan', 'Yen')])
# Out:
# {'India': 'INR', 'USA': ['USD', '$'], 'France': 'Euros', 'Japan': 'Yen'}

# %%
# keys()

# %%
d.keys()
# Out:
# dict_keys(['India', 'USA', 'France', 'Japan'])

# %%
# values()

# %%
d.values()
# Out:
# dict_values(['INR', '$', 'Euros', 'Yen'])

# %%
del d

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11412/3161387801.py in <module>
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
dnew
# Out:
# {'India': 'INR', 'USA': '$', 'France': 'Euros', 'Japan': 'Yen'}

# %%
del dnew['France']

# %%
dnew
# Out:
# {'India': 'INR', 'USA': '$', 'Japan': 'Yen'}

# %%
# update()

# %%
d = {1:'Hi', 2:'Pune'}

d1 = {3:'Hyder', 4: 'Chennai'}

# %%
d.update(d1)

# %%
d
# Out:
# {1: 'Hi', 2: 'Pune', 3: 'Hyder', 4: 'Chennai'}

# %%
d = {1:'Hi', 2:'Pune'}

d1 = {3:'Hyder', 2: 'Chennai'}

# %%
d.update(d1)

# %%
d
# Out:
# {1: 'Hi', 2: 'Chennai', 3: 'Hyder'}

# %%
# popitem()

# %%
d.popitem()
# Out:
# (3, 'Hyder')

# %%
d
# Out:
# {1: 'Hi', 2: 'Chennai'}

# %%
# challenges

# %%
a = {1:{'Hi':'I am inside'}}

# %%
a[1]['Hi']
# Out:
# 'I am inside'

# %%
#2 :

# %%
GDP = {'State':['Goa', 'Delhi', 'Sikkim'] , 'Per Capita' : [25,19,19,17]}

# %%
GDP['State'].append('ASSAM')

# %%
GDP
# Out:
# {'State': ['Goa', 'Delhi', 'Sikkim', 'ASSAM'], 'Per Capita': [25, 19, 19, 17]}

# %%
l = [25,19,19,17]

# %%
l[1] = 19.5

# %%
l
# Out:
# [25, 19.5, 19, 17]

# %%
GDP['Per Capita'][1] = 19.5

# %%
GDP
# Out:
# {'State': ['Goa', 'Delhi', 'Sikkim', 'ASSAM'],
#  'Per Capita': [25, 19.5, 19, 17]}

# %%
GDP['Per Capita'][1] = 23.5

# %%
[25, 19.5, 19, 17][1] = 23

# %%
GDP
# Out:
# {'State': ['Goa', 'Delhi', 'Sikkim', 'ASSAM'],
#  'Per Capita': [25, 23.5, 19, 17]}
