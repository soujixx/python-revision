# %% [markdown]
# - List
#     - Lists are Mutable
#     - It can be collection of elements of different datatypes
#     - They can be indexed
#     - Allow duplicates

# %%
# Initialize the list
L = []

# %%
# creation of list
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist[0] + mylist[2]
# Out:
# 'redgreen'

# %%
mylist[0] + " " + mylist[2]
# Out:
# 'red green'

# %%
mylist[3][1:4]
# Out:
# 'ran'

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
# 1

# %%
mylist[7][1]
# Out:
# 6

# %%
# 2

# %%
mylist[7][-1]
# Out:
# 6

# %%
# 3

# %%
mylist[-1][-1]
# Out:
# 6

# %%
# 4

# %%
mylist[-1][1]
# Out:
# 6

# %%
# 5

# %%
mylist[len(mylist) - 1][1]
# Out:
# 6

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist[1] = 'black'

# %%
mylist
# Out:
# ['red', 'black', 'green', 'orange', 'orange', 1, (1, 2), [5, 6]]

# %%
mylist[1].replace('c','a')
# Out:
# 'blaak'

# %%
mylist

# %%
mylist[1][3] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6944/399298787.py in <module>
# ----> 1 mylist[1][3] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist[1:4]
# Out:
# ['black', 'green', 'orange']

# %%
mylist[::2]
# Out:
# ['red', 'green', 'orange', (1, 2)]

# %%
# please practice all ways of indexing

# %% [markdown]
# # List Methods

# %%
# append()

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist.append(['black', 'Purple'])

# %%
print(mylist)
# Out:
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6], ['black', 'Purple']]

# %%
mylist.append("chennai")

# %%
mylist
# Out:
# ['red',
#  'blue',
#  'green',
#  'orange',
#  'orange',
#  1,
#  (1, 2),
#  [5, 6],
#  ['black', 'Purple'],
#  'chennai']

# %%
# extend()

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist.extend(['black', 'Purple'])

# %%
print(mylist)
# Out:
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6], 'black', 'Purple']

# %%
# copy()

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist1 = mylist

# %%
print(mylist)
print(mylist1)
# Out:
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6]]
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6]]

# %%
mylist.append('Mumbai')

# %%
print(mylist)
print(mylist1)
# Out:
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6], 'Mumbai']
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6], 'Mumbai']

# %%
# s = 'Hyderabad'

# s.replace('d','k')

# s1 = s.replace('d','k')

# print(s)
# print(s1)

# s = 'Hyderabad'

# s1 = s

# s.replace('d','k')

# print(s)
# print(s1)

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist1 = mylist # Shallow copy
mylist2 = mylist.copy() # Deep copy

# %%
mylist.append("Mumbai")

# %%
print(mylist)
print(mylist1)
print(mylist2)
# Out:
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6], 'Mumbai']
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6], 'Mumbai']
# ['red', 'blue', 'green', 'orange', 'orange', 1, (1, 2), [5, 6]]

# %% [markdown]
# ### Identity Operator IS IS NOT

# %%
mylist = ['red', 'blue', 'green', 'orange', 'orange', 1, (1,2), [5,6]]

# %%
mylist1 = mylist # Shallow copy
mylist2 = mylist.copy() # Deep copy

# %%
mylist is mylist1
# Out:
# True

# %%
mylist is mylist2
# Out:
# False

# %%
# count()

# %%
mylist = ['red', 'blue', 'green', 'orange', ['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
mylist.count('orange')
# Out:
# 1

# %%
len(mylist)
# Out:
# 8

# %%
mylist[4].count('orange')
# Out:
# 2

# %%
mylist.count('orange') + mylist[4].count('orange')
# Out:
# 3

# %%
# index()

# %%
mylist = ['red', 'blue', 'green', 'orange', ['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
mylist.index((1,2))
# Out:
# 6

# %%
# insert()

# %%
L1 = ['Pune', 'Mumbai', 'Banglore', 'Chennai' , 'New Delhi', 'Hyderabad']

# %%
L1.insert(2,'Jaipur')

# %%
L1
# Out:
# ['Pune', 'Mumbai', 'Jaipur', 'Banglore', 'Chennai', 'New Delhi', 'Hyderabad']

# %%
# reverse()

# %%
L1.reverse()

# %%
L1
# Out:
# ['Hyderabad', 'New Delhi', 'Chennai', 'Banglore', 'Jaipur', 'Mumbai', 'Pune']

# %%
# sort

# %%
mylist = [1,8,2,6,5]

# %%
mylist.sort()

# %%
mylist
# Out:
# [1, 2, 5, 6, 8]

# %%
mylist.sort(reverse=True)

# %%
mylist
# Out:
# [8, 6, 5, 2, 1]

# %%
mylist = ['red', 'blue', 'green', 'orange','Blue']

# %%
mylist.sort()

# %%
mylist
# Out:
# ['Blue', 'blue', 'green', 'orange', 'red']

# %%
# sorted()

# %%
mylist = [1,8,2,6,5]

# %%
mylist.sort()

# %%
mylist
# Out:
# [1, 2, 5, 6, 8]

# %%
mylist = [1,8,2,6,5]

# %%
mylist1 = sorted(mylist)

# %%
mylist
# Out:
# [1, 8, 2, 6, 5]

# %%
mylist1
# Out:
# [1, 2, 5, 6, 8]

# %%
mylist1 = sorted(mylist, reverse=True)

# %%
mylist1
# Out:
# [8, 6, 5, 2, 1]

# %% [markdown]
# ## Membership Operator

# %%
# in , not in

# %%
myl = [1947, 'black', 'orange', 2020]

# %%
2020 in myl
# Out:
# True

# %%
# remove()

# %%
mylist = ['red', 'blue', 'green', 'orange', ['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
mylist.remove('green')

# %%
mylist
# Out:
# ['red', 'blue', 'orange', ['orange', 'orange', 'Grape'], 1, (1, 2), [5, 6]]

# %%
mylist = ['red', 'blue', 'green', 'orange', 'green',['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
mylist.remove('green')

# %%
print(mylist)
# Out:
# ['red', 'blue', 'orange', 'green', ['orange', 'orange', 'Grape'], 1, (1, 2), [5, 6]]

# %%
# pop()

# %%
mylist = ['red', 'blue', 'green', 'orange', 'green',['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
mylist.pop()
# Out:
# [5, 6]

# %%
print(mylist)
# Out:
# ['red', 'blue', 'green', 'orange', 'green', ['orange', 'orange', 'Grape'], 1, (1, 2)]

# %%
l = mylist.pop()

# %%
print(l)
# Out:
# (1, 2)

# %%
mylist
# Out:
# ['red', 'blue', 'green', 'orange', 'green', ['orange', 'orange', 'Grape'], 1]

# %%
l1 = mylist.pop(5)

# %%
l1
# Out:
# ['orange', 'orange', 'Grape']

# %%
mylist
# Out:
# ['red', 'blue', 'green', 'orange', 'green', 1]

# %%
# del

# %%
mylist = ['red', 'blue', 'green', 'orange', 'green',['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
del mylist

# %%
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15312/7352315.py in <module>
# ----> 1 mylist
#
# NameError: name 'mylist' is not defined

# %%
mylist = ['red', 'blue', 'green', 'orange', 'green',['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
del mylist[3:]

# %%
mylist
# Out:
# ['red', 'blue', 'green']

# %%
mylist = ['red', 'blue', 'green', 'orange', 'green',['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
del mylist[3:5]

# %%
mylist
# Out:
# ['red', 'blue', 'green', ['orange', 'orange', 'Grape'], 1, (1, 2), [5, 6]]

# %%
mylist = ['red', 'blue', 'green', 'orange', 'green',['orange', 'orange', 'Grape'], 1, (1,2), [5,6]]

# %%
del mylist[0::2]

# %%
mylist
# Out:
# ['blue', 'orange', ['orange', 'orange', 'Grape'], (1, 2)]

# %% [markdown]
# #### Nested list

# %%
mylist = [1947, 'black', 'orange', 2022]
mylist1 = ['red', 'blue', 'black']

# %%
mylist2 = [mylist, mylist1]

# %%
mylist2
# Out:
# [[1947, 'black', 'orange', 2022], ['red', 'blue', 'black']]

# %%
mylist2[0][1]
# Out:
# 'black'

# %% [markdown]
# ### Exercise

# %%
L = ['SAS', 'R', 'Python', 'SPSS']

# %%
# Output :  ['SAS', 'R', 'Python', 'SPARK']

# %%
L[3] = 'SPARK'

# %%
L
# Out:
# ['SAS', 'R', 'Python', 'SPARK']

# %% [markdown]
# ### Tuples

# %% [markdown]
# - Tuples are immutable
# - Tuples are ordered sequence of mixed data types
# - Tuples are
